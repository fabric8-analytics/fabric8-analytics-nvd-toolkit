# %%
import re
import sys

import nltk
import numpy as np

from sklearn.pipeline import Pipeline

# nvdlib has be installed (I suggest to use venv for that)
from nvdlib.nvd import NVD

# add the experimental project to the path
sys.path.append("../src")
import toolkit  # import the toolkit

# %% [markdown]
# ### Get the NVD Feed

# %%
# get the nvd feed
feed = NVD.from_feeds(feed_names=[2017])
# update
# feed.update()

# generator
cves = feed.cves()

# assign the cves to the DATA variable and unpack the iterator (iterator does not
# matter to the pipeline, but for the purpose of reusing the DATA in the notebook,
# it is usefull to unpack it)
DATA = list(cves)

# %% [markdown]
# ## Training Example
#
# **NOTE:**
# Part of the pipeline consists of preprocessors, these were presented in [example_preprocessing_pipeline.ipynb](https://github.com/CermakM/fabric8-analytics-POCs/blob/codebase/cves/toolkit/examples/example_preprocessing_pipeline.ipynb)

# %%
toolkit.transformers.Hook.clear_current_instances()

# %%
preprocessing_pipeline = Pipeline(
    steps=[
        (
            'nvd_feed_preprocessor',
            toolkit.preprocessing.NVDFeedPreprocessor(attributes=['description'])
        ),
        (
            'label_preprocessor', 
            toolkit.preprocessing.LabelPreprocessor(
                feed_attributes=['project', 'description'],
                output_attributes=['description'],
                hook=toolkit.transformers.Hook(key='label_hook', func=toolkit.utils.find_)
            )
        ),
        (
            'nltk_preprocessor',
            toolkit.preprocessing.NLTKPreprocessor()
            
        ),
    ]
)

# %%
steps, preps = list(zip(*preprocessing_pipeline.steps))

fit_params = {
    "%s__feed_attributes" % steps[2]: ['description'],
    "%s__output_attributes" % steps[2]: ['label']
}
processed_data = preprocessing_pipeline.fit_transform(X=DATA, **fit_params)

# %%
# we can define custom features to be used in feature extraction process
from toolkit.transformers import feature_hooks

FEATURE_HOOKS = None  # TODO

# %%
train_pipeline = Pipeline(
    steps=[
        (
            'feature_extractor',
            toolkit.transformers.FeatureExtractor(
                feature_hooks=FEATURE_HOOKS
            )
        ),
        (
            'classifier',
            toolkit.transformers.NBClassifier()
        )
    ]
)

# %%
# split the processed data into data and labels (target values)
processed_data = np.array(processed_data)

data, labels = processed_data[:, 0], processed_data[:, 1]

# %%
classifier = train_pipeline.fit_transform(X=data, y=labels)

# %% [markdown]
# ## Evaluation example

# %%
from sklearn.model_selection import train_test_split, KFold

# %%
toolkit.transformers.Hook.clear_current_instances()

# %%
# instantiate feature extractor
feature_extractor = toolkit.transformers.FeatureExtractor(
    feature_hooks=FEATURE_HOOKS
)

# %%
# create the featureset from the evaluation pipeline
# the featureset is an ndarray of feature dicts and labels
featuresets = feature_extractor.fit_transform(X=data, y=labels)
featuresets.shape
# Out:
# (1475,)

# %%
# split the data into train / test set
X_train, X_test, y_train, y_test = train_test_split(
    featuresets, labels,
    test_size = 0.8,  # split in the ratio 1:5 to show how well the model generalizes
    random_state=0
)

X_train.shape, X_test.shape
# Out:
# ((295,), (1180,))

# %%
# retrain on the training data only
classifier.fit(X_train)

# %%
classifier.fit_predict(X_test[:5], sample=True)
# Out:
# array([[[('before', 'ADP'), 0.9909833492556477],
#         [('FenixHosting/fenix-open-source', 'NOUN'), 0.9064562022700459],
#         [('forums/search.php', 'NOUN'), 0.21372401803568966]],
#
#        [[('paintballrefjosh/MaNGOSWebV4', 'NOUN'), 0.788403851302702],
#         [('id', 'ADJ'), 0.043442325778618854],
#         [('inc/admin/template_files/admin.shop.php', 'NOUN'),
#          0.03737965734222141]],
#
#        [[('tcpdump', 'NOUN'), 0.9989017515296756],
#         [('The', 'DET'), 0.47570496458877365],
#         [('parser', 'NOUN'), 0.06491697579798889]],
#
#        [[('an', 'DET'), 0.9992753320700092],
#         [('BlogoText', 'NOUN'), 0.9832626562781991],
#         [('through', 'ADP'), 0.9189169424083068]],
#
#        [[('tcpdump', 'NOUN'), 0.9989017515296756],
#         [('The', 'DET'), 0.47570496458877365],
#         [('parser', 'NOUN'), 0.06491697579798889]]], dtype=object)

# %%
# evaluate the classifier on the test set
accuracy = classifier.evaluate(X_test, y_test, sample=True, n=3)

print("Evaluation accuracy: {:5.3f} %".format(accuracy * 100))
# Out:
# Evaluation accuracy: 87.203 %

# %%
# compute cross validation accuracy
score = toolkit.transformers.cross_validate(classifier,
                                             X_train,
                                             y_train,
                                             shuffle=True,
                                             n=3,
                                             sample=True)

# %%
score
# Out:
# Score(values=array([0.83333333, 0.93333333, 0.8       , 0.83333333, 0.93333333,
#        0.75862069, 0.86206897, 0.86206897, 0.96551724, 0.79310345]), mean=0.8574712643678162, std=0.06450519002553116)

# %%
print("Cross validation accuracy: {:5.2f} (+/- {:5.3f}) %".format(score.mean * 100, score.std * 200))
# Out:
# Cross validation accuracy: 85.75 (+/- 12.901) %

# %% [markdown]
# ## BONUS
#
# Cross validation accuracy visualization

# %%
# visualization tools - NOTE: These do not come in the requirements! (Hence the BONUS)
from plotly import graph_objs as go
from plotly.offline import init_notebook_mode, iplot

# %%
# initialize plotly
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# compute cross validation few more times to get more data
# NOTE: this might take a while to compute
x_val_scores = [
    toolkit.transformers.cross_validate(classifier,
                                             X_train,
                                             y_train,
                                             shuffle=True,
                                             n=3,
                                             sample=True)
    for _ in range(10)
]

# %%
x_val_scores = np.vstack(x_val_scores)

# %%
scores, mean, std = np.hstack(x_val_scores[:, 0]), x_val_scores[:, 1].mean() , x_val_scores[:, 2].std()

# subtract from 1 to get distane from the middle
scores = 1.0 - scores
mean = 1.0 - mean

# show 2x std, as this is stated above as well
std *= 2

rad = np.linspace(0, 360, num=(len(scores) + 1)) * (np.pi / 180.)
rad = rad[:-1]

x = np.cos(rad) * (scores)
y = np.sin(rad) * (scores)
    
data_labels = ["{:5.3f} %".format((1 - score) * 100) for score in scores]
score_trace = go.Scatter(x=x,
                         y=y,
                         mode='markers',
                         hovertext=data_labels,
                         hoverinfo='text')

# %%
cross_validation_layout = {
    'xaxis': {
        'zeroline': False,
    },
    'yaxis': {
        'zeroline': False,
        'scaleanchor': 'x',
        'scaleratio': 1
    },
    'shapes': [
        {
            'type': 'circle',
            'xref': 'x',
            'yref': 'y',
            'x0': -mean,
            'y0': -mean,
            'x1': mean,
            'y1': mean,
            'opacity': 0.1,
            'fillcolor': 'red',
            'line': {
                'color': 'red',
            }
        },
        {
            'type': 'circle',
            'xref': 'x',
            'yref': 'y',
            'x0': -mean - std,
            'y0': -mean - std,
            'x1': mean + std,
            'y1': mean + std,
            'opacity': 0.8,
            'line': {
                'color': 'orange',
                'dash': 'dashdot',
            }
        },
        {
            'type': 'circle',
            'xref': 'x',
            'yref': 'y',
            'x0': -mean + std,
            'y0': -mean + std,
            'x1': mean - std,
            'y1': mean - std,
            'opacity': 0.8,
            'line': {
                'color': 'orange',
                'dash': 'dashdot',
            }
        },
        {
            'type': 'circle',
            'xref': 'x',
            'yref': 'y',
            'x0': -0.001,
            'y0': -0.001,
            'x1': 0.001,
            'y1': 0.001,
            'opacity': 0.8,
            'fillcolor': 'red',
            'line': {
                'color': 'red',
            }
        }
    ]
}

# %%
# visualize cross validation accuracy
fig = {
    'data': [score_trace],
    'layout': cross_validation_layout
}

iplot(fig, show_link=False)
# Out:
# <div id="fd4cac3a-a812-49bf-bb60-79ef0d16da40" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fd4cac3a-a812-49bf-bb60-79ef0d16da40", [{"type": "scatter", "x": [0.1333333333333333, 0.06653511522855142, 0.09921147013144777, 0.09822872507286885, 0.22600273759668055, 0.13118020914415915, 0.19236754880446577, 0.12480373137462344, 0.06043494345130096, 0.05822951210358727, 0.08090169943749473, 0.0770513242775789, 0.14579372548428227, 0.1369094211857377, 0.08498986529982529, 0.14187919882921768, 0.055430358101275494, 0.08306097829339917, 0.0587281781469066, 0.012693950092575084, 0.010300566479164913, 0.04973797743297094, 0.01873813145857245, 0.016711097808573896, 0.008372069270575105, 1.4780219989709436e-17, -0.012991141971582082, -0.03025284948103899, -0.019384273922661163, -0.025726540051536705, -0.02060113295832982, -0.03681245526846779, -0.11354114441735275, -0.09635073482034298, -0.10716535899579935, -0.060805370926807545, -0.043960275155082065, -0.07081521785469193, -0.07541054766428396, -0.10627768865872961, -0.053934466291663145, -0.16886558510040298, -0.14605111334064388, -0.09048270524660194, -0.15496274764804188, -0.1639752614301989, -0.1335976773970526, -0.10161592248917468, -0.20526511061678848, -0.17207357386694339, -0.16666666666666663, -0.2661404609142058, -0.1653524502190796, -0.06548581671524589, -0.06457221074190872, -0.13118020914415918, -0.1923675488044658, -0.12480373137462342, -0.0, -0.11645902420717452, -0.08090169943749474, -0.07705132427757891, -0.07289686274214113, -0.09127294745715846, -0.19122719692460688, -0.020268456975602502, -0.09238393016879261, -0.033224391317359686, -0.05872817814690653, -0.050775800370300404, -0.03090169943749475, -0.04973797743297105, -0.024984175278096613, -0.02506664671286074, -0.008372069270575093, -2.533751998235904e-17, 0.006495570985791074, 0.012965506920445263, 0.025845698563548302, 0.025726540051536715, 0.030901699437494715, 0.024541636845645212, 0.07096321526084542, 0.06423382321356208, 0.08930446582983277, 0.06080537092680753, 0.08792055031016417, 0.09442029047292261, 0.050273698442856014, 0.13284711082341197, 0.13483616572915785, 0.11257705673360202, 0.08763066800438633, 0.24128721399093864, 0.06198509905921675, 0.09838515685811931, 0.10019825804778942, 0.16935987081529116, 0.10263255530839424, 0.20648828864033203], "y": [0.0, 0.004186034635287558, 0.012533323356430422, 0.01873813145857246, 0.05802764033846611, 0.042623033706889316, 0.0761637005554506, 0.0587281781469066, 0.03322439131735969, 0.036953572067517024, 0.0587785252292473, 0.06374239897486896, 0.1369094211857377, 0.14579372548428227, 0.10273509903677187, 0.1952799641594701, 0.08734426815538086, 0.15108735862825237, 0.12480373137462344, 0.0320612581340776, 0.03170188387650511, 0.19371663222572616, 0.09822872507286885, 0.1322819601752637, 0.13307023045710284, 0.24137931034482762, 0.20648828864033203, 0.2394759623862533, 0.10161592248917468, 0.10019825804778941, 0.06340376775301022, 0.09297764858882511, 0.24128721399093858, 0.1752613360087727, 0.16886558510040295, 0.08369141321120145, 0.0531388443293648, 0.07541054766428393, 0.0708152178546919, 0.0879205503101641, 0.03918568348616487, 0.1071653589957993, 0.08029227901695252, 0.04257792915650724, 0.06135409211411295, 0.05327879213361164, 0.034302053402048956, 0.01938427392266116, 0.0259310138408905, 0.010825951642985025, 2.0410779985789216e-17, -0.016744138541150227, -0.020888872260717378, -0.012492087639048315, -0.01657932581099033, -0.042623033706889295, -0.07616370055545059, -0.0587281781469066, -0.0, -0.07390714413503406, -0.05877852522924729, -0.06374239897486896, -0.06845471059286885, -0.09719581698952152, -0.23115397283273684, -0.027897137737067115, -0.14557378025896808, -0.06043494345130096, -0.12480373137462347, -0.1282450325363106, -0.09510565162951533, -0.1937166322 ...
